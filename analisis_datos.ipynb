# %%
import pandas as pd
import numpy as np

# %%
data
# Out:
#     cuota_local  cuota_empate  cuota_visitante  cuota_mas_2.5  \
# 0   cuota_local  cuota_empate  cuota_visitante  cuota_mas_2.5
# 1           2.1          3.55              3.6           2.16
# 2          2.15          3.25              3.8           2.48
# 3          3.25           3.0             2.55           1.52
# 4           2.1           3.2             4.05            2.6
# 5           1.7           3.7             5.65           2.07
# 6          2.05          3.15             4.35           2.38
# 7          1.58           4.1             6.35           2.05
# 8           1.9          3.45             4.55           2.07
# 9          2.35           3.3             3.25           1.52
# 10         1.95          3.45              4.3            1.5
# 11          2.1           3.5             3.65           2.14
# 12         2.05          3.25             4.15           2.43
# 13          2.9           3.1              2.7            2.5
# ...
