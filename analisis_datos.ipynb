# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('base.csv', header = None)

# %%
data
# Out:
#        0     1     2     3     4                       5  \
# 0   2.10  3.55  3.60  2.16  1.71    Atletico Bucaramanga
# 1   2.15  3.25  3.80  2.48  1.55         Deportivo Pasto
# 2   3.25  3.00  2.55  1.52  2.55          Atletico Huila
# 3   2.10  3.20  4.05  2.60  1.50   Once Caldas Manizales
# 4   1.70  3.70  5.65  2.07  1.77         Deportes Tolima
# ..   ...   ...   ...   ...   ...                     ...
# 70  1.57  4.00  6.75  1.98  1.83  Independiente Santa Fe
# 71  1.65  3.80  6.00  2.04  1.79          Millonarios FC
# 72  2.14  3.10  4.10  2.18  1.68    Atletico Bucaramanga
# 73  2.25  3.20  3.60  2.23  1.66  Independiente Medellin
# 74  2.45  3.00  3.30  2.45  1.56     Jaguares de Cordoba
#
#                          6           7    8    9
# 0        Alianza Petrolera  2023-04-25  1.0  1.0
# 1       La Equidad Seguros  2023-04-25  1.0  1.0
# 2   Independiente Medellin  2023-04-25  2.0  3.0
# 3             Boyaca Chico  2023-04-26  1.0  1.0
# ...

# %%
for partido in range(len(data)):
    print(f"el dia {data.iloc[ partido , 7 ]} jugaron { data.iloc[partido ,5] } vs {data.iloc[partido ,6]}, el resultado fue {data.iloc[partido ,8]}, {data.iloc[partido ,9]}, las cuotas que ofrecia Betplay eran {data.iloc[partido ,0]} gana local, {data.iloc[partido ,2]} gana visitante, {data.iloc[partido ,1]} empate.")
# Out:
# el dia 2023-04-25 jugaron Atletico Bucaramanga vs Alianza Petrolera, el resultado fue 1.0, 1.0, las cuotas que ofrecia Betplay eran 2.1 gana local, 3.6 gana visitante, 3.55 empate.
# el dia 2023-04-25 jugaron Deportivo Pasto vs La Equidad Seguros, el resultado fue 1.0, 1.0, las cuotas que ofrecia Betplay eran 2.15 gana local, 3.8 gana visitante, 3.25 empate.
# el dia 2023-04-25 jugaron Atletico Huila vs Independiente Medellin, el resultado fue 2.0, 3.0, las cuotas que ofrecia Betplay eran 3.25 gana local, 2.55 gana visitante, 3.0 empate.
# el dia 2023-04-26 jugaron Once Caldas Manizales vs Boyaca Chico, el resultado fue 1.0, 1.0, las cuotas que ofrecia Betplay eran 2.1 gana local, 4.05 gana visitante, 3.2 empate.
# el dia 2023-04-26 jugaron Deportes Tolima vs Jaguares de Cordoba, el resultado fue 1.0, 1.0, las cuotas que ofrecia Betplay eran 1.7 gana local, 5.65 gana visitante, 3.7 empate.
# ...

# %%
data.iloc[2,2]
# Out:
# 2.55
